# %%
from collections import *
from random import random
def train_char_lm(fname, order=4):
    #data = file(fname).read()
    data=open(fname,"r").read()
    lm = defaultdict(Counter)
    pad = "~" * order
    data = pad + data
    for i in range(len(data)-order):
        history, char = data[i:i+order], data[i+order]
        lm[history][char]+=1
    def normalize(counter):
        s = float(sum(counter.values()))
        return [(c,cnt/s) for c,cnt in counter.items()]
    outlm = {hist:normalize(chars) for hist, chars in lm.items()}
    return outlm

# %%
lm = train_char_lm("shakespeare_input.txt", order=4)

# %%
lm
# Out:
# {'~~~~': [('F', 1.0)],
#  '~~~F': [('i', 1.0)],
#  '~~Fi': [('r', 1.0)],
#  '~Fir': [('s', 1.0)],
#  'Firs': [('t', 1.0)],
#  'irst': [(' ', 0.8337095560571859),
#   (',', 0.08201655379984951),
#   (':', 0.011286681715575621),
#   ('?', 0.004514672686230248),
#   ('y', 0.006019563581640331),
#   ('\n', 0.014296463506395787),
#   ('.', 0.028592927012791574),
#   ('-', 0.008276899924755455),
#   ("'", 0.0007524454477050414),
#   (';', 0.007524454477050414),
#   ('s', 0.0007524454477050414),
#   ('l', 0.0015048908954100827),
#   ('i', 0.0007524454477050414)],
#  'rst ': [('C', 0.09550561797752809),
#   ('f', 0.011235955056179775),
#   ('i', 0.016853932584269662),
#   ('t', 0.05377207062600321),
#   ('u', 0.0016051364365971107),
#   ('S', 0.16292134831460675),
#   ('h', 0.019261637239165328),
#   ('s', 0.03290529695024077),
#   ('R', 0.0008025682182985554),
#   ('b', 0.024879614767255216),
#   ('c', 0.012841091492776886),
#   ('O', 0.018459069020866775),
#   ('w', 0.024077046548956663),
# ...

# %%
lm['hell']
# Out:
# [('!', 0.06912442396313365),
#  (' ', 0.22119815668202766),
#  ("'", 0.018433179723502304),
#  (',', 0.20276497695852536),
#  ('-', 0.059907834101382486),
#  ('.', 0.1336405529953917),
#  ('i', 0.03225806451612903),
#  ('\n', 0.018433179723502304),
#  (':', 0.018433179723502304),
#  (';', 0.027649769585253458),
#  ('?', 0.03225806451612903),
#  ('s', 0.009216589861751152),
#  ('o', 0.15668202764976957)]

# %%
def generate_letter(lm, history, order):
        history = history[-order:]
        dist = lm[history]
        x = random()
        for c,v in dist:
            x = x - v
            if x <= 0: return c
def generate_text(lm, order, nletters=1000):
    history = "~" * order
    out = []
    for i in range(nletters):
        c = generate_letter(lm, history, order)
        history = history[-order:] + c
        out.append(c)
    return "".join(out)

# %%
lm = train_char_lm("shakespeare_input.txt", order=7)

# %%
print(generate_text(lm, 7))
# Out:
# First Citizen:
# O noble princes are blessedly lost ours was beguile me! Why dost thou, I loved my head,
# Or with my revengement taste
# of your oaths and well provide the red plague of all,
# Your rage
# With only in strength: seal to you.
#
# DON PEDRO:
# You'll tell thee word in selfsame words are no worse than my knees, pure with wrinkled on my revenge it, changing wood in tears
# That Rhodes is but oft have my suit,
# And for thou art, by all the kingdom:
# Use us all, believe thee not tell. Virtue is no longer knight, of Northumberland, to bed.
#
# CLEOPATRA:
# Antony, and down:
# I cannot country, be thy suffer surfeited that buzz about the
# world's end
# I'll stay,
# We purpose is, if I were a maid. Thus it is, because thee,
# get us both at any one reckoning upon me,
# As I will run nothing else cross my own report as December. Madam, I will a horse, and the infancy.
# The king and a demand when the cloister: fight
# ...

# %% [markdown]
# # Acknowledgement
# The implementation is taken from [Yoav Goldberg](https://u.cs.biu.ac.il/~yogo/).
# Source: https://nbviewer.jupyter.org/gist/yoavg/d76121dfde2618422139
